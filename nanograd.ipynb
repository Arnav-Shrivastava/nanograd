# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 3*x**2 - 4*x + 5

# %%
f(3.0)
# Out:
# 20.0

# %%
xs = np.arange(-5.0,5.0,0.25)
ys = f(xs)

plt.plot(xs,ys)

# %%
h=0.0000001
x=3.0
(f(x+h)-f(x))/h
# Out:
# 14.000000305713911
